# %%
import pandas as pd
df_aw = pd.read_csv("artworks.csv")
df_at = pd.read_csv("artists.csv")
df_aw
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
# 130261      218011                           Portrait of Takako Saito
#
#        Artist ID                      Name  Date  \
# 0           6210               Otto Wagner  1896
# ...

# %%
df_at["Birth Year"].apply(lambda x: x >= 1981 and x<= 1996).value_counts()
# Out:
# False    14861
# True       230
# Name: Birth Year, dtype: int64

# %%
df_at[(df_at["Nationality"] == "German") & (df_at["Birth Year"].apply(lambda x: x <=1964 and x >= 1946))].Name.value_counts()
# Out:
# Elvira Bach            1
# Thomas Kiesewetter     1
# Cosima von Bonin       1
# Thomas Eggerer         1
# Ingeborg Gabriel       1
#                       ..
# Heribert Ottersbach    1
# Ekkeland Götze         1
# Rolf Kothrade          1
# Hermann Forsterling    1
# Manfred Blank          1
# Name: Name, Length: 139, dtype: int64
